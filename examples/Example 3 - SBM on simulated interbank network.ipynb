# %% [markdown]
# # Example 3. SBM on simulated interbank network

# %% [markdown]
# The difficulty of access to financial data damages the development and evaluation of network models. Nevertheless,  it is possible to gather some information from public sources. We analyzed the paper by Craig and von Peter [*] to reconstruct the German interbank network as the SBM. It includes about 1800 active banks and can be divided into two classes:
# - small highly interconnected core and
# - sparse periphery, those nodes are connected mostly with the core but not with each other.
# Here, we generate an adjacency matrix and applied VIRGMo to it.
#
# [*] https://www.sciencedirect.com/science/article/abs/pii/S1042957314000126

# %%
import numpy as np
np.set_printoptions(precision=2)
import pandas as pd
import sys
sys.path.append('../src/')
from vi_sbm import *
from graph_models import SBM, DCSBM, WSBM, WDCSBM, EdgesDataset
from utils import permute_classes

torch.manual_seed(42)

# %% [markdown]
# ## SBM

# %% [markdown]
# We start with the standard SBM and unweighted directed graphs. First, we generate a graph with 3 classes of nodes.

# %%
N = 1800                             # Number of nodes
num_classes = 2                      # Number of classes
p = torch.tensor([0.025, 0.975])     # Probability of each class
B = torch.tensor([                   # Connection probability between classes
        [0.66, 0.11],
        [0.11, 0.00053]])
sbm = SBM(p, B)
z, A = sbm.generate(N)               # Generate the class assignments z and the adjacency matrix A
sbm.show(sorted=False)               # Show A

# %%
sbm.show(sorted=True)    # Show A sorted by class

# %% [markdown]
# Next, we create a dataloader that transformes the adjacency matrix into a set of (start node, finish node, weight) tupels, fit the SBM to the generated data and show the summary.

# %%
dataloader = DataLoader(EdgesDataset(A), batch_size=int(N**2/128), shuffle=True, num_workers=0)
vi = VI_SBM(num_nodes=N, num_classes=num_classes)
vi.train(dataloader, lrs=[0.1,0.01], epochs=[15,15])
vi.summary(A)
# Out:
# >>>>>>>>>>>> Start training...
# Epoch 1 | LR: 0.10 | Total loss: 603619.19 | Epoch time 17.32
# Epoch 2 | LR: 0.10 | Total loss: 184630.64 | Epoch time 18.88
# Epoch 3 | LR: 0.10 | Total loss: 129427.88 | Epoch time 22.39
# Epoch 4 | LR: 0.10 | Total loss: 105594.10 | Epoch time 19.17
# Epoch 5 | LR: 0.10 | Total loss: 93187.22 | Epoch time 24.75
# Epoch 6 | LR: 0.10 | Total loss: 84754.84 | Epoch time 25.19
# Epoch 7 | LR: 0.10 | Total loss: 78478.01 | Epoch time 21.29
# Epoch 8 | LR: 0.10 | Total loss: 74045.77 | Epoch time 20.47
# Epoch 9 | LR: 0.10 | Total loss: 71206.50 | Epoch time 26.44
# Epoch 10 | LR: 0.10 | Total loss: 69507.82 | Epoch time 25.72
# Epoch 11 | LR: 0.10 | Total loss: 68529.75 | Epoch time 24.48
# Epoch 12 | LR: 0.10 | Total loss: 67941.17 | Epoch time 23.18
# Epoch 13 | LR: 0.10 | Total loss: 67592.24 | Epoch time 26.97
# Epoch 14 | LR: 0.10 | Total loss: 67372.12 | Epoch time 27.02
# Epoch 15 | LR: 0.10 | Total loss: 67214.55 | Epoch time 27.16
# Epoch 16 | LR: 0.01 | Total loss: 67116.28 | Epoch time 21.98
# Epoch 17 | LR: 0.01 | Total loss: 67043.24 | Epoch time 20.11
# Epoch 18 | LR: 0.01 | Total loss: 66982.34 | Epoch time 22.61
# Epoch 19 | LR: 0.01 | Total loss: 66937.91 | Epoch time 24.83
# Epoch 20 | LR: 0.01 | Total loss: 66896.78 | Epoch time 19.85
# Epoch 21 | LR: 0.01 | Total loss: 66872.98 | Epoch time 24.10
# Epoch 22 | LR: 0.01 | Total loss: 66842.63 | Epoch time 26.69
# Epoch 23 | LR: 0.01 | Total loss: 66822.22 | Epoch time 26.07
# Epoch 24 | LR: 0.01 | Total loss: 66796.21 | Epoch time 23.73
# Epoch 25 | LR: 0.01 | Total loss: 66772.62 | Epoch time 23.66
# Epoch 26 | LR: 0.01 | Total loss: 66757.25 | Epoch time 25.34
# Epoch 27 | LR: 0.01 | Total loss: 66746.00 | Epoch time 21.36
# Epoch 28 | LR: 0.01 | Total loss: 66731.21 | Epoch time 27.11
# Epoch 29 | LR: 0.01 | Total loss: 66719.48 | Epoch time 25.28
# Epoch 30 | LR: 0.01 | Total loss: 66711.62 | Epoch time 23.63
# >>>>>>>>>>>> Training is finished.
# Classes probability [0.02 0.98]
# Edges probability:
#  [[6.72e-01 1.15e-01]
#  [1.08e-01 5.56e-04]]

# %%
q_eta, q_theta, q_B = vi.constrained_params()    # Get the parameters

# %%
permutation = [0,1]  # You may have to change the permutation
q_theta_perm = q_theta.detach()[permutation]
num_samples = 1000
theta_samples = Dirichlet(q_theta_perm).sample([num_samples])

# %%
import seaborn as sns
sns.set()

# %%
fig, axs = plt.subplots(1, num_classes, figsize=(12, 3), sharey=True)
bins, alpha = 20, 0.8
for i in range(num_classes):
    axs[i].hist(theta_samples[:,i], bins=bins, alpha=alpha) 
    axs[i].vlines(p[i], 0, num_samples*0.15, colors='r')
fig.suptitle(r'Posterior class probabilities $\theta$', fontsize=18)
plt.show()

# %%
q_B_perm = q_B.detach()[permutation,:,:][:,permutation,:]
B_samples = Beta(q_B_perm[:,:,0], q_B_perm[:,:,1]).sample([num_samples])

# %%
fig, axs = plt.subplots(num_classes, num_classes, figsize=(12, 12), sharey=True)
bins, alpha = 20, 0.8
for i in range(num_classes):
    for j in range(num_classes):
        axs[i,j].hist(B_samples[:,i, j], bins=bins, alpha=alpha) 
        axs[i,j].vlines(B[i,j], 0, num_samples*0.15, colors='r')
fig.suptitle(r'Posterior connection probabilities $B$', fontsize=18)
plt.show()
