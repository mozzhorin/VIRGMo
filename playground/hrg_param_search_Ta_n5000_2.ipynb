# %%
import sys
sys.path.append('../src/')
#from vi_hrg_log1pexp import *
from vi_hrg_fix import *
from utils import *
from torch import autograd
torch.manual_seed(88)

# %%
N = 5000
R = torch.tensor([8.0]).double()
alpha = torch.tensor([0.55]).double()
T = torch.tensor([0.3]).double()

G = HRG(R=R, alpha=alpha, T=T)
r, theta, A = G.generate(N)
r, theta, A = r.float(), theta.float(), A.float()
G.show()
#G.plot()

# %% [markdown]
# ### True values

# %%
tv = hrg_likelihood(A, r, theta, R, T, alpha, debug=False)
tv
# Out:
# -3018608.450039673

# %%
#Rs = torch.arange(6., 10.5, 0.5)
Ts = torch.arange(0.02, 0.42, 0.02)
alphas = torch.arange(.02, 1.02, .02)

# %%
lh_a = []
for a in alphas:
    lh_ =[]
    for t in Ts:
        lh_.append(hrg_likelihood(A, r, theta, R, t, a, debug=False))
    lh_a.append(lh_)

# %%
#lh_a = np.load('paramsearchTa_n5000_R8_T03_a055.npy')

# %%
lh_a = np.array(lh_a)
lh_clampd = torch.clamp(torch.tensor(lh_a), min=-0.304*1e+7)

# %%
#np.save('paramsearchTa_n5000_R8_T03_a055_1.npy', lh_a)

# %%
#levels = [-1960, -1980, -2000, -2500, -3000, -3500, -4000, -5000, -6000, -10000]

# %%
max_index = np.unravel_index(lh_a.argmax(), lh_a.shape)
a_max = alphas[max_index[0]].item()
T_max = Ts[max_index[1]].item()
a_max, T_max
# Out:
# (0.18000000715255737, 0.30000001192092896)

# %%
max_index
# Out:
# (8, 14)

# %%
plt.figure(figsize=(10,8))
im = plt.contour(Ts.numpy(), alphas.numpy(), lh_clampd, alpha=1.)
plt.scatter(T_max, a_max, color='blue', marker='x', label=str('Max value: log_lh %.2f' % lh_clampd.max().item()))
plt.scatter(T.numpy(), alpha.numpy(), color='red', marker='x', label=str('True value: log_lh %.2f' % tv))
plt.title('Likelihood (R=8)', fontsize=14)
plt.xlabel('T', fontsize=14)
plt.ylabel(r'$\alpha$', fontsize=14)
plt.colorbar(im)
plt.legend()
plt.show()

# %%
lh_clampd.max(), lh_clampd[max_index]
# Out:
# (tensor(-3016153.0351, dtype=torch.float64),
#  tensor(-3016153.0351, dtype=torch.float64))

# %% [raw]
# fig, axs = plt.subplots(len(alphas),1, figsize=(10, 110))
# #fig.subplots_adjust(hspace = .5, wspace=.05)
# #axs = axs.ravel()
# #fig.suptitle(title, size=24)
#
# for i in range(len(alphas)):
#     im = axs[i].contourf(Ts.numpy(), Rs.numpy(), lh_clampd[i], alpha=0.7)
#     if alphas[i].item()==alpha:
#         axs[i].scatter(T.numpy(), R.numpy(), color='red')
#     if alphas[i].item()==a_max:
#         axs[i].scatter(T_max, R_max, color='blue')
#     axs[i].set_title(str('alpha = %.2f' %  alphas[i].item()), fontsize=14)
#     axs[i].set_xlabel('T', fontsize=14)
#     axs[i].set_ylabel('R', fontsize=14)
#
#     fig.colorbar(im, ax=axs[i])
#
# plt.show()

# %% [raw]
# plt.plot(alphas, lh_a[:,max_index[1],max_index[2]])
# plt.show()
